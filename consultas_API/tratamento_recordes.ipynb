# %%
import pandas as pd

# %%
df1 = pd.read_csv("output/recordes_natacao_Male.csv")

# %%
df = df1.copy()

# %%
df = df.loc[df["Event"] == "100 FR LCM"]
df.head()
# Out:
#     Rank       Event Swim Time            Name Gender  \
# 29     1  100 FR LCM     46.40      Zhanle PAN   Male
# 30     2  100 FR LCM     46.80      Zhanle PAN   Male
# 31     3  100 FR LCM     46.86  David Popovici   Male
# 32     4  100 FR LCM     46.91     Cesar Cielo   Male
# 33     5  100 FR LCM     46.94   Alain Bernard   Male
#
#                          Team            Swimmer Country  \
# 29  Peoples Republic of China  Peoples Republic of China
# 30  Peoples Republic of China  Peoples Republic of China
# 31                    Romania                    Romania
# 32                     Brazil                     Brazil
# 33                     France                     France
#
#                                    Meet   Swim Date
# 29                   2024 Olympic Games  07/31/2024
# 30                    2024 World Champs  02/11/2024
# 31  LEN European Aquatics Championships  08/13/2022
# 32                    2009 World Champs  07/30/2009
# ...

# %%
df["Year"] = df["Swim Date"].str[-4:]
df["Year"] = pd.to_numeric(df["Year"])
df = df.loc[df["Year"] >1970]
df.drop(columns=["Event", "Gender", "Swim Date", "Swimmer Country"], inplace=True)
df.rename(columns={"Swim Time": "Results", "Meet": "Competition"}, inplace=True)
df.sort_values(by="Year", ascending=False)
df.head()
# Out:
#     Rank Results            Name                       Team  \
# 29     1   46.40      Zhanle PAN  Peoples Republic of China
# 30     2   46.80      Zhanle PAN  Peoples Republic of China
# 31     3   46.86  David Popovici                    Romania
# 32     4   46.91     Cesar Cielo                     Brazil
# 33     5   46.94   Alain Bernard                     France
#
#                             Competition  Year
# 29                   2024 Olympic Games  2024
# 30                    2024 World Champs  2024
# 31  LEN European Aquatics Championships  2022
# 32                    2009 World Champs  2009
# 33             2009 FRA National Champs  2009

# %%
df.to_csv("output/recordes_tratados_homens.csv", index=False)

# %%
df1 = pd.read_csv("output/recordes_female.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df1 = pd.read_csv("output/recordes_female.csv")
#
# File c:\Users\davic\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = df1.copy()
df = df.loc[df["Event"] == "100 FR LCM"]
df["Year"] = df["Swim Date"].str[-4:]
df["Year"] = pd.to_numeric(df["Year"])
df = df.loc[df["Year"] >1970]
df.drop(columns=["Event", "Gender", "Swim Date", "Swimmer Country"], inplace=True)
df.rename(columns={"Swim Time": "Results", "Meet": "Competition"}, inplace=True) 
df.sort_values(by="Year", ascending=False)
df.head()
# Out:
#     Rank Results            Name       Team  \
# 14     1   51.71  Sarah Sjostrom     Sweden
# 15     2   52.06   Cate Campbell  Australia
# 16     3   52.07  Britta Steffen    Germany
# 17     4   52.22  Britta Steffen    Germany
# 18     5   52.56  Britta Steffen    Germany
#
#                            Competition  Year
# 14                   2017 World Champs  2017
# 15  2016 Swimming Australia Grand Prix  2016
# 16                   2009 World Champs  2009
# 17                   2009 World Champs  2009
# 18                 2008 Olympic Invite  2009

# %%
df.to_csv("output/recordes_tratados_mulheres.csv", index=False)
